# %% [markdown]
# # CSO QaQc: Alaska Exploration
#
# Here's where I explore a domain in Alaska to get a feel for the CSO data there. This is in the hopes to eventually compare the data there to some form of Climatalogy or other snow modelling tool. (Particularily C-SNOW which Nina had sent me a link to)
#
# C-SNOW: https://ees.kuleuven.be/project/c-snow/

# %%
import requests
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.io.img_tiles as cimgt
import folium

# Import necessary packages, may need more or less as I go.

# %%
CSO_AL = gpd.read_file('CSO_AL.geojson')
CSO_AL['timestamp'] = pd.to_datetime(CSO_AL.timestamp)
CSO_AL['flags'] = False
CSO_AL
# Out:
#             id               author       depth       source  \
# 0     kUEn0QAu  Tully LaBelle-Hamer   44.000000    SnowPilot
# 1     ntTyn4to  Tully LaBelle-Hamer   35.000000    SnowPilot
# 2     6RjAtewN        Eric  Geisler  108.000000    SnowPilot
# 3     XJt9Rv2N        Joseph Kurtak  165.000000    SnowPilot
# 4     PFF0tx0k        Joseph Kurtak  165.000000    SnowPilot
# ...        ...                  ...         ...          ...
# 1340  mHxyj/1g        Joseph Kurtak  104.999996  MountainHub
# 1341  pNIGyuBz         Henry Munter  500.000000    SnowPilot
# 1342  GOdT7bJp         Eric Roberts  285.000000    SnowPilot
# 1343  c43cn8+7         Henry Munter  169.000000    SnowPilot
# 1344  0PEPVY9c            Lee House  145.000000  MountainHub
#
#                             timestamp   elevation  \
# 0           2016-11-27 02:11:33+00:00  887.579956
# 1           2016-12-04 00:43:14+00:00  706.499512
# 2           2017-01-23 05:55:58+00:00  699.366577
# 3           2017-01-24 07:51:04+00:00  713.650757
# 4           2017-01-24 07:51:18+00:00  713.650757
# ...                               ...         ...
# 1340 2020-02-27 19:39:51.181999+00:00  373.305969
# 1341        2020-02-28 20:00:00+00:00  697.370850
# 1342        2020-02-28 23:30:00+00:00  562.470947
# 1343        2020-02-29 19:15:00+00:00  967.541260
# 1344 2020-02-29 21:16:41.721001+00:00  450.126862
#
#                          geometry  flags
# 0     POINT (-149.18541 60.76332)  False
# 1     POINT (-149.18781 60.76411)  False
# 2     POINT (-149.43802 60.68470)  False
# 3     POINT (-149.43286 60.68269)  False
# 4     POINT (-149.43286 60.68269)  False
# ...                           ...    ...
# 1340  POINT (-149.47248 60.67653)  False
# 1341  POINT (-149.11024 60.68881)  False
# 1342  POINT (-149.15773 60.78556)  False
# 1343  POINT (-148.71820 60.92633)  False
# 1344  POINT (-135.35146 57.09307)  False
#
# [1345 rows x 8 columns]

# %% [markdown]
# The domain that I've created comes from Alaska and extends a bit into Canada with coordinates:
#
# `Lattitude range`: (67.5) - (50)
#
# `Longitude range`: (-135) - (-165)

# %%
CSO_AL.plot();

# %%
bnd = CSO_AL.geometry.bounds
stamen_terrain = cimgt.Stamen('terrain-background')
dx, dy = 0.4, 0.2

fig, ax = plt.subplots(
    figsize=(12, 12), subplot_kw={"projection": stamen_terrain.crs}
)
ax.set_extent([bnd.minx.min() - dx, bnd.maxx.max() + dx, bnd.miny.min() - dy, bnd.maxy.max() + dy])

ax.add_image(stamen_terrain, 8)
CSO_AL.plot(ax=ax, column='source', categorical=True, legend=True, transform=ccrs.PlateCarree());

# %% [markdown]
# This is just for a big look at the data in a more literal sense.

# %% [markdown]
# ## Data Exploration
#
# Here we'll be looking for any biases in the data such as Zeros and Snow Probe lengths.

# %%
CSO_AL[['source', 'depth']].groupby(['source']).agg(['count', 'min', 'max'])
# Out:
#             depth
#             count  min    max
# source
# MountainHub  1139  0.0  762.0
# SnowPilot     206  0.0  650.0

# %%
ZERO = 0
CSO_AL.loc[CSO_AL['depth'] <= ZERO, 'flags'] = True

# %% [markdown]
# Already we notice a very large number of `MountainHub` entries when compared to `SnowPilot`

# %%
CSO_ALzeros = CSO_AL.loc[CSO_AL['flags'] == True]
CSO_ALzeros
# Out:
#             id                  author  depth       source  \
# 22    nN2mfe0/                Luc Mehl    0.0    SnowPilot
# 63    wA6UuACA  Katreen Wikstrom Jones    0.0  MountainHub
# 102   ACGpKHy+  Katreen Wikstrom Jones    0.0  MountainHub
# 115   YubxeKH0  Katreen Wikstrom Jones    0.0  MountainHub
# 116   PGve5nES  Katreen Wikstrom Jones    0.0  MountainHub
# 165   LuQBD52i  Katreen Wikstrom Jones    0.0  MountainHub
# 183   OpdlXY8L  Katreen Wikstrom Jones    0.0  MountainHub
# 309   gE/0gXf3          Gabriel Wolken    0.0  MountainHub
# 316   b2ZP8O8c             Bobby Liebs    0.0  MountainHub
# 318   MhiNyK3w             Bobby Liebs    0.0  MountainHub
# 523   9Ztc55F+             Emily Baker    0.0  MountainHub
# 534   OPYaHXUK         Jeff  Moskowitz    0.0    SnowPilot
# 584   C/OkiXjo           Joseph Kurtak    0.0    SnowPilot
# 605   p6OPKXit           Joseph Kurtak    0.0  MountainHub
# 685   wpHSzQWi              steve reid    0.0    SnowPilot
# 1024  jcnILKo9             Emily Baker    0.0  MountainHub
#
#                             timestamp    elevation  \
# 22          2017-02-21 04:11:45+00:00  1237.794556
# 63   2017-03-17 20:24:44.387001+00:00   806.347229
# 102  2017-03-18 18:26:21.174000+00:00   750.456970
# 115  2017-03-18 19:06:32.404999+00:00   809.416565
# 116  2017-03-18 19:07:45.035000+00:00   809.045776
# 165  2017-03-18 23:36:55.570999+00:00   837.614197
# 183  2017-03-19 00:33:21.357000+00:00   778.325684
# 309  2017-04-25 04:03:04.676000+00:00   334.803772
# 316  2017-04-25 17:01:41.965000+00:00   495.185486
# 318  2017-04-25 17:19:23.622999+00:00   492.385162
# 523  2017-10-27 00:22:54.430000+00:00    51.578075
# 534         2017-11-13 20:21:48+00:00  1046.725830
# 584         2017-12-02 04:08:22+00:00  1022.562439
# 605  2017-12-14 21:33:22.745001+00:00   166.837143
# 685         2018-02-08 00:22:52+00:00  1335.961304
# 1024 2018-05-22 22:49:53.007999+00:00   363.361664
#
#                          geometry  flags
# 22    POINT (-145.42256 61.17650)   True
# 63    POINT (-145.75648 61.14137)   True
# 102   POINT (-145.74489 61.14416)   True
# 115   POINT (-145.75133 61.14372)   True
# 116   POINT (-145.75152 61.14363)   True
# 165   POINT (-145.71486 61.14118)   True
# 183   POINT (-145.74226 61.13946)   True
# 309   POINT (-147.95387 64.92998)   True
# 316   POINT (-145.54982 61.20162)   True
# 318   POINT (-145.48232 61.20843)   True
# 523   POINT (-149.80619 61.18913)   True
# 534   POINT (-136.60978 59.72867)   True
# 584   POINT (-149.50604 61.25635)   True
# 605   POINT (-149.77687 61.11378)   True
# 685   POINT (-135.08463 59.63843)   True
# 1024  POINT (-148.89407 60.37059)   True

# %%
CSO_ALzeros[['source', 'elevation']].groupby(['source']).agg(['count', 'min', 'max'])
# Out:
#             elevation
#                 count          min          max
# source
# MountainHub        12    51.578075   837.614197
# SnowPilot           4  1022.562439  1335.961304

# %% [markdown]
# Zeros aren't going to have much of an effect on the data. We know that most of them are true `ZERO` values as they come from `MountainHub`, some of them come from `SnowPilot` and we know that means there could have been some mistake but that is still up in the air. Eiter way they will not effect the dataset too heavily as its 16 values whereas this dataset has 1345 entries.

# %%
Depth1 = 240
Depth2 = 300
Depth3 = 450
DELTA = 1

# %% [markdown]
# These are common snow probe lengths that we can check for bias in. (See `CSOLARGE.ipynb` for methodology)

# %% [markdown]
# `Depth1` test for Alaska.

# %%
CSO_AL['flags'] = False
CSO_AL.loc[(CSO_AL['depth'].between(Depth1 - DELTA, Depth1 + DELTA)), 'flags'] = True
CSO_ALDepth1 = CSO_AL.loc[CSO_AL['flags'] == True]
CSO_ALDepth1
# Out:
#             id                  author       depth       source  \
# 298   AvkKsbow             Kevin Salys  239.999991  MountainHub
# 308   mUfMfRhb            Sarah Carter  240.000000  MountainHub
# 504   eqK3t6qG             Kevin Salys  239.999991  MountainHub
# 723   A3+d2c6L             Bobby Liebs  241.000000  MountainHub
# 806   RsrqWZ9x  Katreen Wikstrom Jones  240.000000  MountainHub
# 1011  eYDhAgrN          Taylor Crocker  239.000000    SnowPilot
# 1012  yZN3xgXB          Taylor Crocker  239.000000  MountainHub
# 1323  EkwrBVoM            Eric Roberts  240.000000    SnowPilot
# 1325  2ktGWh6m            Eric Roberts  240.000000    SnowPilot
#
#                             timestamp    elevation  \
# 298  2017-04-13 07:29:21.509001+00:00  1719.303955
# 308  2017-04-25 02:00:58.297001+00:00  1131.534180
# 504  2017-05-01 19:30:16.577000+00:00   862.540161
# 723  2018-03-11 22:54:03.315000+00:00   248.960236
# 806  2018-03-28 22:27:58.089001+00:00   445.174652
# 1011        2018-04-18 00:43:53+00:00  1145.558716
# 1012 2018-04-18 01:15:05.445000+00:00  1228.763062
# 1323        2020-02-09 21:00:00+00:00   559.518738
# 1325        2020-02-10 00:45:00+00:00   556.565247
#
#                          geometry  flags
# 298   POINT (-145.77593 61.18249)   True
# 308   POINT (-145.59949 61.00782)   True
# 504   POINT (-145.72962 61.13359)   True
# 723   POINT (-149.12642 60.81474)   True
# 806   POINT (-149.19039 60.79079)   True
# 1011  POINT (-149.26010 61.79434)   True
# 1012  POINT (-149.25619 61.79458)   True
# 1323  POINT (-149.15663 60.78599)   True
# 1325  POINT (-149.16249 60.78558)   True

# %% [markdown]
# `Depth2` test for Alaska.

# %%
CSO_AL['flags'] = False
CSO_AL.loc[(CSO_AL['depth'].between(Depth2 - DELTA, Depth2 + DELTA)), 'flags'] = True
CSO_ALDepth2 = CSO_AL.loc[CSO_AL['flags'] == True]
CSO_ALDepth2
# Out:
#             id                  author   depth       source  \
# 279   jPPX7y1d              Chris Palm  300.00  MountainHub
# 350   cmZhj9VF  Katreen Wikstrom Jones  300.00  MountainHub
# 379   ENjzS6Ov  Katreen Wikstrom Jones  300.00  MountainHub
# 1006  YtCSKVzS             Alex Rogers  299.72  MountainHub
# 1125  2IHyRKwT            Wendy Wagner  300.00  MountainHub
# 1212  GSu20o2u             Sean Marble  300.00    SnowPilot
# 1316  NyYGRT2f            Eric Roberts  300.00    SnowPilot
# 1327  Ovy8BAc2            Henry Munter  300.00    SnowPilot
#
#                             timestamp    elevation  \
# 279  2017-04-06 00:33:14.059000+00:00  1969.480835
# 350  2017-04-30 18:49:30.237000+00:00   870.593689
# 379  2017-04-30 20:01:54.337002+00:00   901.215149
# 1006 2018-04-09 18:52:40.627998+00:00   636.010986
# 1125 2019-02-13 20:12:30.257000+00:00  1013.587646
# 1212        2019-04-07 22:30:00+00:00  1243.666138
# 1316        2020-02-04 22:20:00+00:00   561.746704
# 1327        2020-02-11 21:17:00+00:00   702.343628
#
#                          geometry  flags
# 279   POINT (-151.19604 62.69941)   True
# 350   POINT (-145.72615 61.12942)   True
# 379   POINT (-145.72490 61.13080)   True
# 1006  POINT (-145.68959 61.17529)   True
# 1125  POINT (-149.28444 60.80715)   True
# 1212  POINT (-145.68250 63.33610)   True
# 1316  POINT (-149.15728 60.78569)   True
# 1327  POINT (-148.80688 61.13417)   True

# %% [markdown]
# `Depth3` test for Alaska.

# %%
CSO_AL['flags'] = False
CSO_AL.loc[(CSO_AL['depth'].between(Depth3 - DELTA, Depth3 + DELTA)), 'flags'] = True
CSO_ALDepth3 = CSO_AL.loc[CSO_AL['flags'] == True]
CSO_ALDepth3
# Out:
# Empty GeoDataFrame
# Columns: [id, author, depth, source, timestamp, elevation, geometry, flags]
# Index: []

# %% [markdown]
# From observation it once again looks like `300` and `240` cm are the most common values that come from the data. I feel like it would be worth checking to see if they also show up as the `modes` of the dataframe (excluding 0) as that would almost guarantee some sort of bias.

# %%
CSO_AL.mode()['depth'][0]
# Out:
# /Users/kamrankazemi/opt/miniconda3/envs/cso_obsdata/lib/python3.9/site-packages/pandas/core/algorithms.py:944: UserWarning: Unable to sort modes: '<' not supported between instances of 'Point' and 'Point'
#   warn(f"Unable to sort modes: {err}")
# 70.0

# %% [markdown]
# Interestingly the `mode` of the data is 70 cm?
#
# Also for some reason the `CSO_AL.mode()['depth'][0]` command takes quite a long time. I think it has to do with the error. I'll ask Emilio on what it means/how I could maybe make it faster in the case where I may want to do this for the whole database.

# %%
found_mode = 70.0
CSO_AL['flags'] = False
CSO_AL.loc[CSO_AL['depth'] == found_mode, 'flags'] = True
CSO_ALmode = CSO_AL.loc[CSO_AL['flags'] == True]
CSO_ALmode
# Out:
#             id                  author  depth       source  \
# 12    0aGGq++t                      EB   70.0  MountainHub
# 15    SfD2nTFj                      EB   70.0  MountainHub
# 42    v1HqQjao          Gabriel Wolken   70.0  MountainHub
# 77    V9tAovDk          Gabriel Wolken   70.0  MountainHub
# 154   /HxA0rCb  Katreen Wikstrom Jones   70.0  MountainHub
# 191   vI80+Jcw  Katreen Wikstrom Jones   70.0  MountainHub
# 236   TPvTHTOC            Sarah Carter   70.0  MountainHub
# 417   kRDTqhTn            Naomi F. Ray   70.0  MountainHub
# 616   HjTyEbiA         Jordan Haffener   70.0    SnowPilot
# 617   ktK2DknI         Jordan Haffener   70.0    SnowPilot
# 618   k6gph9PN         Jordan Haffener   70.0    SnowPilot
# 619   ziV1lFSR         Jordan Haffener   70.0    SnowPilot
# 642   2teCL+pW  Katreen Wikstrom Jones   70.0  MountainHub
# 643   1UYQ3t8r  Katreen Wikstrom Jones   70.0  MountainHub
# 718   P+r5CYHd       MichelleJohannsen   70.0  MountainHub
# 736   QESxbEyi             Jane Wolken   70.0  MountainHub
# 787   mpOBFiU7  Katreen Wikstrom Jones   70.0  MountainHub
# 790   mizESHS9  Katreen Wikstrom Jones   70.0  MountainHub
# 843   td35op1R              Don Sharaf   70.0    SnowPilot
# 858   sq1MYYZh  Katreen Wikstrom Jones   70.0  MountainHub
# 939   rjaBXrNV          Max Wittenberg   70.0    SnowPilot
# 1057  72+0BlOO               Alan Abel   70.0    SnowPilot
# 1081  8muL0qRV          Brittany Price   70.0    SnowPilot
# 1129  RyqNgRXD            Gareth Brown   70.0  MountainHub
# 1167  HV6Yax2r  Katreen Wikstrom Jones   70.0  MountainHub
# 1168  dewkbd5p  Katreen Wikstrom Jones   70.0  MountainHub
#
#                             timestamp    elevation  \
# 12   2017-02-09 02:38:58.502998+00:00   679.753113
# 15   2017-02-11 23:19:59.007999+00:00  1034.680664
# 42   2017-03-14 04:20:22.159000+00:00   373.201965
# 77   2017-03-17 21:59:39.851002+00:00   837.592957
# 154  2017-03-18 22:59:12.189000+00:00   753.491272
# 191  2017-03-19 00:43:36.130001+00:00   785.238098
# 236  2017-03-19 23:51:40.714001+00:00    55.168133
# 417  2017-04-30 22:32:07.051000+00:00   709.860535
# 616         2017-12-23 03:51:45+00:00   937.974670
# 617         2017-12-23 03:51:58+00:00   601.812134
# 618         2017-12-23 03:52:18+00:00   601.812134
# 619         2017-12-23 03:54:08+00:00   601.812134
# 642  2018-01-14 21:45:28.902000+00:00   483.428375
# 643  2018-01-14 22:03:20.966000+00:00   488.725281
# 718  2018-03-04 23:34:52.258999+00:00  1042.736450
# 736  2018-03-17 20:53:47.452999+00:00   357.363861
# 787  2018-03-27 21:27:38.105000+00:00   237.649002
# 790  2018-03-27 21:58:01.674000+00:00   227.387115
# 843         2018-03-31 02:29:24+00:00  1278.265503
# 858  2018-04-05 20:07:48.148998+00:00   931.366150
# 939         2018-04-07 15:35:30+00:00  1224.104126
# 1057        2018-12-13 20:00:00+00:00   780.010254
# 1081        2018-12-28 21:21:00+00:00  1153.241089
# 1129 2019-02-20 17:53:21.580999+00:00   995.868042
# 1167 2019-03-08 23:04:57.307999+00:00   636.615906
# 1168 2019-03-08 23:05:43.106998+00:00   528.527222
#
#                          geometry  flags
# 12    POINT (-149.65950 61.09644)   True
# 15    POINT (-149.33518 61.76801)   True
# 42    POINT (-147.95350 64.92978)   True
# 77    POINT (-145.75397 61.13529)   True
# 154   POINT (-145.73072 61.14145)   True
# 191   POINT (-145.74018 61.13954)   True
# 236   POINT (-146.00895 61.05984)   True
# 417   POINT (-145.71940 61.16100)   True
# 616   POINT (-149.47011 60.62982)   True
# 617   POINT (-149.47011 60.62982)   True
# 618   POINT (-149.47011 60.62982)   True
# 619   POINT (-149.47011 60.62982)   True
# 642   POINT (-148.04306 64.87785)   True
# 643   POINT (-148.04385 64.87771)   True
# 718   POINT (-145.62773 63.23695)   True
# 736   POINT (-147.95376 64.92991)   True
# 787   POINT (-149.25677 60.74918)   True
# 790   POINT (-149.26148 60.74196)   True
# 843   POINT (-147.06360 61.64514)   True
# 858   POINT (-145.72050 61.13264)   True
# 939   POINT (-145.77512 60.90043)   True
# 1057  POINT (-149.19507 60.82238)   True
# 1081  POINT (-149.53300 61.13600)   True
# 1129  POINT (-145.04162 61.51574)   True
# 1167  POINT (-147.41553 65.04606)   True
# 1168  POINT (-147.40961 65.05504)   True

# %%
histogram_AL = CSO_AL['depth'].hist(bins = 30)

# %% [markdown]
# ## Side Exploration
#
# I still haven't checked the modes from the other domains. Out of curiosity I'm going to check `CSO_UT.geojson` and `CSO_CA.geojson` just to see what comes up.

# %%
CSO_CA = gpd.read_file('CSO_CA.geojson')
CSO_UT = gpd.read_file('CSO_UT.geojson')

# %%
CSO_CA.mode()['depth'][0]
# Out:
# /Users/kamrankazemi/opt/miniconda3/envs/cso_obsdata/lib/python3.9/site-packages/pandas/core/algorithms.py:944: UserWarning: Unable to sort modes: '<' not supported between instances of 'Point' and 'Point'
#   warn(f"Unable to sort modes: {err}")
# 0.0

# %%
CSO_UT.mode()['depth'][0]
# Out:
# 65.0

# %% [markdown]
# ## C-SNOW Exploration
#
# I'm going to start becoming comfortable with using `C-SNOW` to eventually start using it for data comparison and exploration of the Alaskan domain.
